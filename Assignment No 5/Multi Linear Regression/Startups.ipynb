# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.formula.api as smf
from sklearn import linear_model
from sklearn.metrics import r2_score
from statsmodels.graphics.regressionplots import influence_plot

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv(r"C:\Users\HP\OneDrive\Desktop\Assignment DS (Husen)\Assignment No 5\50_Startups.csv")
df
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# ...

# %%
df["State"].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df1=df.drop("State",axis=1)
df1.head(11)
# Out:
#     R&D Spend  Administration  Marketing Spend     Profit
# 0   165349.20       136897.80        471784.10  192261.83
# 1   162597.70       151377.59        443898.53  191792.06
# 2   153441.51       101145.55        407934.54  191050.39
# 3   144372.41       118671.85        383199.62  182901.99
# 4   142107.34        91391.77        366168.42  166187.94
# 5   131876.90        99814.71        362861.36  156991.12
# 6   134615.46       147198.87        127716.82  156122.51
# 7   130298.13       145530.06        323876.68  155752.60
# 8   120542.52       148718.95        311613.29  152211.77
# 9   123334.88       108679.17        304981.62  149759.96
# 10  101913.08       110594.11        229160.95  146121.95

# %%
df1.isnull().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# Profit             0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   Profit           50 non-null     float64
# dtypes: float64(4)
# memory usage: 1.7 KB

# %%
df1.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
df1.corr()
# Out:
#                  R&D Spend  Administration  Marketing Spend    Profit
# R&D Spend         1.000000        0.241955         0.724248  0.972900
# Administration    0.241955        1.000000        -0.032154  0.200717
# Marketing Spend   0.724248       -0.032154         1.000000  0.747766
# Profit            0.972900        0.200717         0.747766  1.000000

# %%
# sns.set_style(style="darkgrid")


sns.pairplot(df1)

# %%
fig, ax=plt.subplots(figsize=(8,8))
sns.heatmap(df1.corr(),cmap="magma",annot=True,fmt=".3f")
# Out:
# <AxesSubplot:>

# %%
sns.regplot(x = 'Profit', y = 'R&D Spend', data =df1)
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='R&D Spend'>

# %%
sns.regplot(x = 'Profit', y = 'Administration', data =df1)
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Administration'>

# %%
sns.regplot(x = 'Profit', y = 'Marketing Spend', data =df1)
# Out:
# <AxesSubplot:xlabel='Profit', ylabel='Marketing Spend'>

# %% [markdown]
# # Model Building

# %% [markdown]
# ## using sklearn

# %%
x=df1.drop(["Profit"],axis=1).values
y=df1.iloc[:,3].values.reshape(-1,1)
x
# Out:
# array([[165349.2 , 136897.8 , 471784.1 ],
#        [162597.7 , 151377.59, 443898.53],
#        [153441.51, 101145.55, 407934.54],
#        [144372.41, 118671.85, 383199.62],
#        [142107.34,  91391.77, 366168.42],
#        [131876.9 ,  99814.71, 362861.36],
#        [134615.46, 147198.87, 127716.82],
#        [130298.13, 145530.06, 323876.68],
#        [120542.52, 148718.95, 311613.29],
#        [123334.88, 108679.17, 304981.62],
#        [101913.08, 110594.11, 229160.95],
#        [100671.96,  91790.61, 249744.55],
#        [ 93863.75, 127320.38, 249839.44],
#        [ 91992.39, 135495.07, 252664.93],
#        [119943.24, 156547.42, 256512.92],
#        [114523.61, 122616.84, 261776.23],
#        [ 78013.11, 121597.55, 264346.06],
#        [ 94657.16, 145077.58, 282574.31],
#        [ 91749.16, 114175.79, 294919.57],
#        [ 86419.7 , 153514.11,      0.  ],
#        [ 76253.86, 113867.3 , 298664.47],
#        [ 78389.47, 153773.43, 299737.29],
# ...

# %%
model=linear_model.LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.rank_
# Out:
# 3

# %%
model.coef_
# Out:
# array([[ 0.80571505, -0.02681597,  0.02722806]])

# %%
model.intercept_
# Out:
# array([50122.19298987])

# %%
r2_score(y,model.predict(x))
# Out:
# 0.9507459940683246

# %% [markdown]
# ## Prediction

# %%
df2=pd.DataFrame({"R&D Spend":153450,"Administration":134300,"Marketing Spend":472000},index=[1])
model.predict(df2)
print("The profit will be:",model.predict(df2))
# Out:
# The profit will be: [[183009.42943001]]

# %% [markdown]
# # Using stats.ols

# %%
df3=df1.rename({"Marketing Spend":"Marketing_Spend"},axis=1)
df4=df3.rename({"R&D Spend":"RnD_Spend"},axis=1)
df4.head(1)
# Out:
#    RnD_Spend  Administration  Marketing_Spend     Profit
# 0   165349.2        136897.8         471784.1  192261.83

# %%
module=smf.ols("Profit~RnD_Spend+Administration+Marketing_Spend",data=df4).fit()
module.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Profit   R-squared:                       0.951
# Model:                            OLS   Adj. R-squared:                  0.948
# Method:                 Least Squares   F-statistic:                     296.0
# Date:                Tue, 14 Feb 2023   Prob (F-statistic):           4.53e-30
# Time:                        16:25:17   Log-Likelihood:                -525.39
# No. Observations:                  50   AIC:                             1059.
# Df Residuals:                      46   BIC:                             1066.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Test for Normality of Residules(Q-Q plot)

# %%
import statsmodels.api as smf 

qqplot=smf.qqplot(module.resid,line="q")

# line = 45 to draw the diagnoal line

# %% [markdown]
# # Residual plot for Homoscedasticity

# %%
def std(values):
    return (values - values.mean())/values.std()

plt.scatter(std(module.fittedvalues),
           std(module.resid))

# %% [markdown]
# # Residual Vs Regressors

# %%
fig=plt.figure(figsize=(15,8))
fig=smf.graphics.plot_regress_exog(module,"RnD_Spend",fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = smf.graphics.plot_regress_exog(module, "Marketing_Spend", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %%
fig = plt.figure(figsize=(15,8))
fig = smf.graphics.plot_regress_exog(module, "Administration", fig=fig)
plt.show()
# Out:
# eval_env: 1

# %% [markdown]
# # Model Deletion diagnostic

# %% [markdown]
# ## Detacting Influnencers/Outliers

# %%
module_influence=module.get_influence()
(c, _)=module_influence.cooks_distance

# %%
influence_plot(module)
plt.show()

# %%
np.argmax(c),np.max(c)
# Out:
# (49, 0.28808229275432634)

# %% [markdown]
# ### Since the value is <1,we dosent need to do the diagnostic process  and finalize the model

# %%
(module.rsquared,module.aic)
# Out:
# (0.9507459940683246, 1058.7714985998055)

# %%
module.params
# Out:
# Intercept          50122.192990
# RnD_Spend              0.805715
# Administration        -0.026816
# Marketing_Spend        0.027228
# dtype: float64
